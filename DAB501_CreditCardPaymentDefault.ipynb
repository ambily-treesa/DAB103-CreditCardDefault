# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ls drive/MyDrive/DAB501_Project1/
# Out:
# default_of_credit_card_clients.xls

# %% [markdown]
# # Importing the dataset

# %%
file_path = 'drive/MyDrive/DAB501_Project1/default_of_credit_card_clients.xls'

df = pd.read_excel(file_path, index_col=0)
df.head()
# Out:
#            X1   X2         X3        X4   X5     X6     X7     X8     X9  \
# ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4
# 1       20000    2          2         1   24      2      2     -1     -1
# 2      120000    2          2         2   26     -1      2      0      0
# 3       90000    2          2         2   34      0      0      0      0
# 4       50000    2          2         1   37      0      0      0      0
#
#       X10  ...        X15        X16        X17       X18       X19       X20  \
# ID  PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 1      -2  ...          0          0          0         0       689         0
# 2       0  ...       3272       3455       3261         0      1000      1000
# 3       0  ...      14331      14948      15549      1518      1500      1000
# 4       0  ...      28314      28959      29547      2000      2019      1200
#
#          X21       X22       X23                           Y
# ID  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 1          0         0         0                           1
# 2       1000         0      2000                           1
# 3       1000      1000      5000                           0
# 4       1100      1069      1000                           0
#
# [5 rows x 24 columns]
